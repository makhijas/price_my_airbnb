# %%
import numpy as np 
import pandas as pd

# %%
seattle_df = pd.read_csv("data/airbnb-listings.csv", error_bad_lines=False, sep = ";")

# %%
seattle_df.columns
# Out:
# Index(['ID', 'Listing Url', 'Scrape ID', 'Last Scraped', 'Name', 'Summary',
#        'Space', 'Description', 'Experiences Offered', 'Neighborhood Overview',
#        'Notes', 'Transit', 'Access', 'Interaction', 'House Rules',
#        'Thumbnail Url', 'Medium Url', 'Picture Url', 'XL Picture Url',
#        'Host ID', 'Host URL', 'Host Name', 'Host Since', 'Host Location',
#        'Host About', 'Host Response Time', 'Host Response Rate',
#        'Host Acceptance Rate', 'Host Thumbnail Url', 'Host Picture Url',
#        'Host Neighbourhood', 'Host Listings Count',
#        'Host Total Listings Count', 'Host Verifications', 'Street',
#        'Neighbourhood', 'Neighbourhood Cleansed',
#        'Neighbourhood Group Cleansed', 'City', 'State', 'Zipcode', 'Market',
#        'Smart Location', 'Country Code', 'Country', 'Latitude', 'Longitude',
#        'Property Type', 'Room Type', 'Accommodates', 'Bathrooms', 'Bedrooms',
# ...

# %%
seattle_df_drop = seattle_df.drop(columns = ['ID', 'Scrape ID', 'Access', 'Interaction', 'House Rules',
       'Picture Url', 
       'Host ID', 'Host Response Rate',
       'Security Deposit', 'Cleaning Fee',
       'Extra People', 'License', 'Geolocation', 'Features','Square Feet', 'Price', 'Weekly Price',
       'Monthly Price','Host Acceptance Rate', 'Longitude', 'Latitude', 'Notes', 'Neighborhood Overview', 'Transit'])

# %%
seattle_df_drop.head()
# Out:
#                              Listing Url Last Scraped  \
# 0   https://www.airbnb.com/rooms/2508568   2016-07-07
# 1  https://www.airbnb.com/rooms/13728582   2016-07-07
# 2   https://www.airbnb.com/rooms/1909058   2016-01-04
# 3   https://www.airbnb.com/rooms/9550869   2016-01-04
# 4  https://www.airbnb.com/rooms/10234558   2016-01-04
#
#                                  Name  \
# 0  HUGE 2 BR/2 BA Mission Beach Condo
# 1                    Groovy beach pad
# 2     Queen Anne Private Bed and Bath
# 3                Queen Anne Craftsman
# 4  Cozy BR in heart of lively Ballard
#
#                                              Summary  \
# 0  This huge 2 bedroom condo has over 2000 square...
# 1  Resort-like amenities, close proximity to beac...
# 2  Enjoy a quiet stay in our comfortable 1915 Cra...
# 3  Beautiful craftsman in the center of Queen Ann...
# 4  Quite and comfy room for two with private bath...
#
#                                                Space  \
# ...

# %%
seattle_df_drop.shape
# Out:
# (4685, 65)

# %%
seattle_df_drop.isnull().sum()
# Out:
# Listing Url                         0
# Last Scraped                        0
# Name                                0
# Summary                           194
# Space                             683
# Description                         0
# Experiences Offered                 0
# Thumbnail Url                     561
# Medium Url                        561
# XL Picture Url                    561
# Host URL                            0
# Host Name                           2
# Host Since                          2
# Host Location                       8
# Host About                        900
# Host Response Time                675
# Host Thumbnail Url                  2
# Host Picture Url                    2
# Host Neighbourhood                396
# Host Listings Count                 2
# Host Total Listings Count           2
# Host Verifications                  1
# Street                              0
# Neighbourhood                     573
# Neighbourhood Cleansed              0
# ...

# %%
sum(pd.isnull(seattle_df_drop['State']))
# Out:
# 10

# %%
sum(pd.isnull(seattle_df_drop['Zipcode']))
# Out:
# 22

# %%
print ('market:', sum(pd.isnull(seattle_df_drop['Market'])))
print ('Smart Location:', sum(pd.isnull(seattle_df_drop['Smart Location'])))
print ('Country Code:', sum(pd.isnull(seattle_df_drop['Country Code'])))
print ('Country:', sum(pd.isnull(seattle_df_drop['Country'])))
# Out:
# market: 3
# Smart Location: 0
# Country Code: 0
# Country: 0

# %%
seattle_df_drop.columns
# Out:
# Index(['Listing Url', 'Last Scraped', 'Name', 'Summary', 'Space',
#        'Description', 'Experiences Offered', 'Thumbnail Url', 'Medium Url',
#        'XL Picture Url', 'Host URL', 'Host Name', 'Host Since',
#        'Host Location', 'Host About', 'Host Response Time',
#        'Host Thumbnail Url', 'Host Picture Url', 'Host Neighbourhood',
#        'Host Listings Count', 'Host Total Listings Count',
#        'Host Verifications', 'Street', 'Neighbourhood',
#        'Neighbourhood Cleansed', 'Neighbourhood Group Cleansed', 'City',
#        'State', 'Zipcode', 'Market', 'Smart Location', 'Country Code',
#        'Country', 'Property Type', 'Room Type', 'Accommodates', 'Bathrooms',
#        'Bedrooms', 'Beds', 'Bed Type', 'Amenities', 'Guests Included',
#        'Minimum Nights', 'Maximum Nights', 'Calendar Updated',
#        'Has Availability', 'Availability 30', 'Availability 60',
#        'Availability 90', 'Availability 365', 'Calendar last Scraped',
# ...

# %%
sea_df_host = seattle_df_drop[['Host Name', 'Host Since', 'Host Location', 'Host Response Time',
       'Host Neighbourhood', 'Host Listings Count',
       'Host Total Listings Count', 'Host Verifications','Calculated host listings count']]

# %%
sea_df_reviews = seattle_df_drop[['Host Name','Number of Reviews', 'First Review', 'Last Review',
       'Review Scores Rating', 'Review Scores Accuracy',
       'Review Scores Cleanliness', 'Review Scores Checkin',
       'Review Scores Communication', 'Review Scores Location',
       'Review Scores Value','Reviews per Month']]

# %%
sea_df_location = seattle_df_drop[['Host Name','Street', 'Neighbourhood',
       'Neighbourhood Cleansed', 'Neighbourhood Group Cleansed', 'City',
       'State', 'Zipcode', 'Market', 'Smart Location', 'Country Code',
       'Country',]]

# %%
sea_df_property = seattle_df_drop[['Host Name','Property Type', 'Room Type', 'Accommodates', 'Bathrooms',
       'Bedrooms', 'Beds', 'Bed Type', 'Amenities', 'Guests Included', 'Last Scraped', 'Name', 'Experiences Offered', ]]

# %%
sea_df_availability = seattle_df_drop[['Host Name', 'Minimum Nights', 'Maximum Nights', 'Calendar Updated',
       'Has Availability', 'Availability 30', 'Availability 60',
       'Availability 90', 'Availability 365', 'Calendar last Scraped']]

# %%
sea_df_property.head()
# Out:
#        Host Name Property Type        Room Type  Accommodates  Bathrooms  \
# 0             Dj     Apartment  Entire home/apt             7        2.0
# 1         Kelsey   Condominium  Entire home/apt             4        1.0
# 2  Gary And Beth         House     Private room             2        1.0
# 3        Maureen      Bungalow  Entire home/apt            10        3.0
# 4         Sophia   Condominium     Private room             2        1.0
#
#    Bedrooms  Beds  Bed Type  \
# 0       2.0   4.0  Real Bed
# 1       1.0   1.0  Real Bed
# 2       1.0   1.0  Real Bed
# 3       4.0   4.0  Real Bed
# 4       1.0   1.0  Real Bed
#
#                                            Amenities  Guests Included  \
# 0  {TV,"Cable TV",Internet,"Wireless Internet",Ki...                6
# 1  {Internet,"Wireless Internet","Air Conditionin...                2
# 2  {"Wireless Internet","Free Parking on Premises...                1
# ...

# %%
sea_df_host.head()
# Out:
#        Host Name  Host Since                         Host Location  \
# 0             Dj  2013-09-17  San Diego, California, United States
# 1         Kelsey  2016-03-07  San Diego, California, United States
# 2  Gary And Beth  2012-05-30    Seattle, Washington, United States
# 3        Maureen  2014-03-06    Seattle, Washington, United States
# 4         Sophia  2015-04-25    Seattle, Washington, United States
#
#   Host Response Time Host Neighbourhood  Host Listings Count  \
# 0     within an hour      Mission Beach                  1.0
# 1     within an hour        Linda Vista                  1.0
# 2     within an hour         Queen Anne                  1.0
# 3       within a day         Queen Anne                  1.0
# 4     within an hour                NaN                  1.0
#
#    Host Total Listings Count  \
# 0                        1.0
# 1                        1.0
# 2                        1.0
# 3                        1.0
# 4                        1.0
#
# ...

# %%
sea_df_reviews.head()
# Out:
#        Host Name  Number of Reviews First Review Last Review  \
# 0             Dj                 68   2014-04-11  2016-06-20
# 1         Kelsey                  0          NaN         NaN
# 2  Gary And Beth                 58   2014-01-27  2015-12-07
# 3        Maureen                  0          NaN         NaN
# 4         Sophia                  0          NaN         NaN
#
#    Review Scores Rating  Review Scores Accuracy  Review Scores Cleanliness  \
# 0                  92.0                     9.0                        9.0
# 1                   NaN                     NaN                        NaN
# 2                  99.0                    10.0                       10.0
# 3                   NaN                     NaN                        NaN
# 4                   NaN                     NaN                        NaN
#
#    Review Scores Checkin  Review Scores Communication  Review Scores Location  \
# ...

# %%
sea_df_availability.head()
# Out:
#        Host Name  Minimum Nights  Maximum Nights Calendar Updated  \
# 0             Dj               3             365       a week ago
# 1         Kelsey               2              12        yesterday
# 2  Gary And Beth               3              14      5 weeks ago
# 3        Maureen               1            1125       3 days ago
# 4         Sophia               1            1125        yesterday
#
#   Has Availability  Availability 30  Availability 60  Availability 90  \
# 0              NaN                0               12               33
# 1              NaN                3               13               17
# 2                t               20               49               71
# 3                t               30               60               90
# 4                t               20               50               80
#
#    Availability 365 Calendar last Scraped
# 0               308            2016-07-06
# 1                17            2016-07-06
# ...

# %%
sea_df_location.head()
# Out:
#        Host Name                                             Street  \
# 0             Dj  Mission Boulevard, San Diego, CA 92109, United...
# 1         Kelsey    Friars Road, San Diego, CA 92108, United States
# 2  Gary And Beth  10th Avenue West, Seattle, WA 98119, United St...
# 3        Maureen  10th Avenue West, Seattle, WA 98119, United St...
# 4         Sophia       NW 57th St, Seattle, WA 98107, United States
#
#    Neighbourhood Neighbourhood Cleansed Neighbourhood Group Cleansed  \
# 0  Mission Beach            Mission Bay                          NaN
# 1    Linda Vista         Moreno Mission                          NaN
# 2     Queen Anne        West Queen Anne                   Queen Anne
# 3     Queen Anne        West Queen Anne                   Queen Anne
# 4            NaN                  Adams                      Ballard
#
#         City State Zipcode     Market Smart Location Country Code  \
# 0  San Diego    CA   92109  San Diego  San Diego, CA           US
# ...

# %%
sea_df_location.loc[sea_df_location['Zipcode'] == '98107']
# Out:
#                Host Name                                             Street  \
# 4                 Sophia       NW 57th St, Seattle, WA 98107, United States
# 5                Pallavi  Northwest 62nd Street, Seattle, WA 98107, Unit...
# 6                  Karen  Northwest 57th Street, Seattle, WA 98107, Unit...
# 7                  Chris  Northwest 60th Street, Seattle, WA 98107, Unit...
# 8          Javier & Yeon  Northwest 60th Street, Seattle, WA 98107, Unit...
# 9                 Steven  Northwest 51st Street, Seattle, WA 98107, Unit...
# 61            Jacqueline  2nd Avenue Northwest, Seattle, WA 98107, Unite...
# 102               Lauren  Northwest Market Street, Seattle, WA 98107, Un...
# 103                Debra  Northwest 59th Street, Seattle, WA 98107, Unit...
# 104                Paula  24th Avenue Northwest, Seattle, WA 98107, Unit...
# 105   Sea To Sky Rentals  20th Ave NW and NW 59th St, Seattle, WA 98107,...
# ...

# %%
sea_df_property.loc[sea_df_property['Accommodates'] == 0]
# Out:
# Empty DataFrame
# Columns: [Host Name, Property Type, Room Type, Accommodates, Bathrooms, Bedrooms, Beds, Bed Type, Amenities, Guests Included, Last Scraped, Name, Experiences Offered]
# Index: []

# %%
seattle_df['Price'].isnull().sum()
# Out:
# 4040
